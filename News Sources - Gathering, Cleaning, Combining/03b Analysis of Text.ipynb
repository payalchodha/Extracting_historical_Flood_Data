# %% [markdown]
# # Analysis of Text
#
# **Purpose:** In this notebook the individual keyword searches are combined into one dataframe with an additional column which is related to what keyword search the row was created from.

# %%
# Libraries 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %matplotlib inline

# %%
# Read in the new csv file
# Notice: additional  parse_dates argument     
combined_df= pd.read_csv("../data/combined.csv",
                            parse_dates = ["date"])

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1225 entries, 0 to 1224
# Data columns (total 4 columns):
# index     1225 non-null int64
# date      1225 non-null datetime64[ns]
# source    1225 non-null object
# text      1225 non-null object
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 38.4+ KB

# %%
# check if have any duplicated articles 
dups = combined_df["text"]
combined_df[dups.isin(dups[dups.duplicated()])].sort_values("text")
# Out:
# Empty DataFrame
# Columns: [index, date, source, text]
# Index: []

# %%
# function to make dataframe from search_keywords
def imp_sentences(dataframe, search_keywords):

    sentences_list = []
    
    numeric_words = [" zero","one ", " two", " three", " four", " five", " six", 
                 "seven", "eight", "nine", " ten", "eleven", "twelve", "thirteen", "fourteen",
                 "fifteen", "sixteen", "seventeen", "eighteen", "nineteen","twenty",
                 "thirty", "forty", "fifty", "sixty", "seventy", "eighty", "ninety",
                 "hundred", "thousand", "million", "billion", "trillion"]


    # function for finding string with a number in it
    def hasnumber(inputsentence):
        return bool(re.search(r'\d', inputsentence))
    
    # function for finding string with numeric word in it
    def hasnumword(inputsentence):
        has_numericword = False
        for keyword in numeric_words:
            if len(re.findall(keyword,inputsentence))>0:
                has_numericword = True
        return has_numericword

    # loop through the entire dataframe
    for idx in range(0,dataframe.shape[0]):
        row = dataframe.iloc[idx,:]

        # split the row on ". " 
        # sentences = row["text"].split(". " )
        sentences = re.split(r'\.\D', row["text"])
        date = row["date"]
        source = row["source"]

        # for each sentence of the row
        for sentence in sentences:
            has_keyword = False
            for keyword in search_keywords:
                #if sentence has keyword:
                # length will be greater than zero
                if len(re.findall(keyword, sentence))>0:
                     #set has_keyword to True
                    has_keyword=True
                     #break out of the loop
                    break

            number_bool = hasnumber(sentence) 
            has_numericword = hasnumword(sentence)

            # if the sentence has at least one of the keywords
            if (has_keyword == True and number_bool == True) or (has_keyword == True and has_numericword == True) :
                sentence_info = {}
                sentence_info["date"] = date
                sentence_info["source"] = source
                sentence_info['sentence'] = sentence
                # add the sentence and the date to the sentence list
                sentences_list.append(sentence_info)  
                
    search_keywords_df =  pd.DataFrame(sentences_list)
    return search_keywords_df

# %%
# keywords

total_keywords= ['crop', 'livestock', 'cattle', "farm", 'wheat', 'rice', 'barley',
                 'agricult', 'acre',
                'death', ' die', 'dead','kill', 'drown', "mortality",
                'victim', 'suffer', 'rescue', 'missing', 'evacuat', 'help', 'affect',
                'relief', 'wound', 'survive', 'displace', 'strand','lost', 'damag',
                'destroy', 'econom', 'cost', 'rehabilit'
                'house', 'home', 'roof', 'street', 'road', 'bridge']
# find total search_keywords
imp_sentences(combined_df, total_keywords)
# Out:
#            date                                             source  \
# 0    2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 1    2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 2    2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 3    2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 4    2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# ...         ...                                                ...
# 3394 2007-07-17                  https://reliefweb.int/node/244592
# 3395 2007-07-17                  https://reliefweb.int/node/244592
# 3396 2007-07-17                  https://reliefweb.int/node/244592
# 3397 2007-07-17                  https://reliefweb.int/node/244592
# 3398 2007-07-17                  https://reliefweb.int/node/244592
#
#                                                sentence
# 0        flood-hit farmers to get 9k-quintal wheat seed
# 1     jalandhar, october 20  in a major initiative a...
# 2     he said in total, 25,000 quintals of wheat see...
# 3     he said of this, nearly 9,000 quintals of seed...
# 4       chief agriculture officer naazar singh said ...
# ...                                                 ...
# 3394     - 8239 people are staying in 93 relief centres
# 3395  - due to landslide in darjeeling, the national...
# 3396  - about 105378 people are still staying in 373...
# 3397  loss of human lives -as per provisional inform...
# 3398  the cumulative number of people who lost their...
#
# [3399 rows x 3 columns]

# %%
total_keyword_one_search_df= imp_sentences(combined_df, total_keywords)

# %%
total_keyword_one_search_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3399 entries, 0 to 3398
# Data columns (total 3 columns):
# date        3399 non-null datetime64[ns]
# source      3399 non-null object
# sentence    3399 non-null object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 79.8+ KB

# %%
# Find duplicated sentences based on duplicated text  in the total_keyword search
dups = total_keyword_one_search_df["sentence"]
total_keyword_one_search_df[dups.isin(dups[dups.duplicated()])].sort_values("sentence")
# Out:
#            date                                             source  \
# 2336 2010-07-12                  https://reliefweb.int/node/361003
# 2328 2010-07-13                  https://reliefweb.int/node/360959
# 3371 2007-08-17                  https://reliefweb.int/node/240777
# 3343 2007-08-18                  https://reliefweb.int/node/240663
# 2556 2009-07-29                  https://reliefweb.int/node/318915
# ...         ...                                                ...
# 2150 2014-09-15                  https://reliefweb.int/node/691554
# 2147 2014-09-15                  https://reliefweb.int/node/691734
# 2161 2014-09-15                  https://reliefweb.int/node/691554
# 1938 2013-08-06  https://www.dainiktribuneonline.com/2013/08/वर...
# 1941 2013-08-06  https://www.dainiktribuneonline.com/2013/08/वर...
#
#                                                sentence
# 2336   - 05 teams of 8th bn ndrf consisting of 206 p...
# 2328   - 05 teams of 8th bn ndrf consisting of 206 p...
# 3371   - 1437 villages in 19 districts with populati...
# 3343   - 1437 villages in 19 districts with populati...
# 2556        - 19454 livestock have been perished so far
# ...                                                 ...
# 2150  thirty generator sets of 3 to 5 kva capacity h...
# 2147  to restore the road connectivity, five task fo...
# 2161  to restore the road connectivity, five task fo...
# 1938  udhiana 6 august nine torrential rains for mor...
# 1941  udhiana 6 august nine torrential rains for mor...
#
# [535 rows x 3 columns]

# %%
#keywords
agri_keywords=['crop', 'livestock', 'cattle', "farm", 'wheat', 'rice', 'barley',
              'agricult', 'acre'
              ]

# find agriculture data 
imp_sentences(combined_df, agri_keywords)
# Out:
#            date                                             source  \
# 0    2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 1    2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 2    2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 3    2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 4    2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# ...         ...                                                ...
# 1111 2008-08-15                  https://reliefweb.int/node/277055
# 1112 2008-06-16                  https://reliefweb.int/node/270161
# 1113 2007-08-18                  https://reliefweb.int/node/240663
# 1114 2007-08-17                  https://reliefweb.int/node/240777
# 1115 2007-08-17                  https://reliefweb.int/node/240777
#
#                                                sentence
# 0        flood-hit farmers to get 9k-quintal wheat seed
# 1     jalandhar, october 20  in a major initiative a...
# 2     he said in total, 25,000 quintals of wheat see...
# 3     he said of this, nearly 9,000 quintals of seed...
# 4       chief agriculture officer naazar singh said ...
# ...                                                 ...
# 1111  - 344 cattle/livestock are reported to have be...
# 1112  india: assam reels under floods, orissa sounds...
# 1113  - 341 cattle camps continue to run in the affe...
# 1114   - several low lying areas and agricultural fi...
# 1115  - 341 cattle camps continue to run in the affe...
#
# [1116 rows x 3 columns]

# %%
agri_df = imp_sentences(combined_df, agri_keywords)

# %%
# add column named to specify what type it is 
agri_df["topic"] = "agri"

# check
agri_df.head()
# Out:
#         date                                             source  \
# 0 2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 1 2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 2 2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 3 2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 4 2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
#
#                                             sentence topic
# 0     flood-hit farmers to get 9k-quintal wheat seed  agri
# 1  jalandhar, october 20  in a major initiative a...  agri
# 2  he said in total, 25,000 quintals of wheat see...  agri
# 3  he said of this, nearly 9,000 quintals of seed...  agri
# 4    chief agriculture officer naazar singh said ...  agri

# %%
# keywords 
death_keywords=['death', ' die', 'dead','kill', 'drown', "mortality"]

# find sentences related to death
imp_sentences(combined_df, death_keywords)
# Out:
#           date                                             source  \
# 0   2019-09-14  https://www.tribuneindia.com/news/punjab/jalan...
# 1   2019-09-12  https://www.tribuneindia.com/news/punjab/punja...
# 2   2019-09-03  https://www.tribuneindia.com/news/punjab/rs-4-...
# 3   2019-09-02  https://www.tribuneindia.com/news/punjab/power...
# 4   2019-08-27  https://www.tribuneindia.com/news/punjab/distr...
# ..         ...                                                ...
# 411 2007-08-18                  https://reliefweb.int/node/240663
# 412 2007-08-18                  https://reliefweb.int/node/240663
# 413 2007-08-17                  https://reliefweb.int/node/240777
# 414 2007-08-17                  https://reliefweb.int/node/240777
# 415 2007-07-17                  https://reliefweb.int/node/244592
#
#                                               sentence
# 0    ush({ });  in kapurthala, crop losses have bee...
# 1    initial assessment  6 persons died  1,400 inju...
# 2    our correspondent fazilka, september 2  family...
# 3     as many as 25,000 personnel from different de...
# 4    in his desperate call to the pcr at 6.57 pm on...
# ..                                                 ...
# 411   - 06 human deaths have been reported in the s...
# 412  loss of human lives - as per provisional infor...
# 413  out of the missing, dead bodies of only 08 per...
# 414  loss of human lives - as per provisional infor...
# 415  loss of human lives -as per provisional inform...
#
# [416 rows x 3 columns]

# %%
# create dataframe 
death_df = imp_sentences(combined_df, death_keywords)

# add column named to specify what type it is 
death_df["topic"] = "death"

# check
death_df.head()
# Out:
#         date                                             source  \
# 0 2019-09-14  https://www.tribuneindia.com/news/punjab/jalan...
# 1 2019-09-12  https://www.tribuneindia.com/news/punjab/punja...
# 2 2019-09-03  https://www.tribuneindia.com/news/punjab/rs-4-...
# 3 2019-09-02  https://www.tribuneindia.com/news/punjab/power...
# 4 2019-08-27  https://www.tribuneindia.com/news/punjab/distr...
#
#                                             sentence  topic
# 0  ush({ });  in kapurthala, crop losses have bee...  death
# 1  initial assessment  6 persons died  1,400 inju...  death
# 2  our correspondent fazilka, september 2  family...  death
# 3   as many as 25,000 personnel from different de...  death
# 4  in his desperate call to the pcr at 6.57 pm on...  death

# %%
death_df.loc[100].sentence
# Out:
# ' a few hours after the death of her husband and two daughters, the woman gave birth to twins at a private hospital'

# %%
# keywords
lives_keywords = ['victim', 'suffer', 'rescue', 'missing', 'evacuat', 'help', 'affect',
                  'relief', 'wound', 'survive', 'displace', 'strand','lost', 'damag',
                  'destroy', 'econom', 'cost', 'rehabilit',
                 ]

# find the lives data 
imp_sentences(combined_df, lives_keywords)
# Out:
#            date                                             source  \
# 0    2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 1    2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 2    2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 3    2019-10-16  https://www.tribuneindia.com/news/punjab/debt-...
# 4    2019-10-16  https://www.tribuneindia.com/news/punjab/debt-...
# ...         ...                                                ...
# 1959 2007-07-17                  https://reliefweb.int/node/244592
# 1960 2007-07-17                  https://reliefweb.int/node/244592
# 1961 2007-07-17                  https://reliefweb.int/node/244592
# 1962 2007-07-17                  https://reliefweb.int/node/244592
# 1963 2007-07-17                  https://reliefweb.int/node/244592
#
#                                                sentence
# 0     jalandhar, october 20  in a major initiative a...
# 1     he said in total, 25,000 quintals of wheat see...
# 2     he said of this, nearly 9,000 quintals of seed...
# 3      according to a proposal, farmers in 14 distri...
# 4     ush({ });  according to estimates prepared by ...
# ...                                                 ...
# 1959     - 8239 people are staying in 93 relief centres
# 1960  - due to landslide in darjeeling, the national...
# 1961  - about 105378 people are still staying in 373...
# 1962  loss of human lives -as per provisional inform...
# 1963  the cumulative number of people who lost their...
#
# [1964 rows x 3 columns]

# %%
# create dataframe 
lives_df = imp_sentences(combined_df, lives_keywords)

# add column named to specify what type it is 
lives_df["topic"] = "lives"

# check
lives_df.head()
# Out:
#         date                                             source  \
# 0 2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 1 2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 2 2019-10-21  https://www.tribuneindia.com/news/punjab/flood...
# 3 2019-10-16  https://www.tribuneindia.com/news/punjab/debt-...
# 4 2019-10-16  https://www.tribuneindia.com/news/punjab/debt-...
#
#                                             sentence  topic
# 0  jalandhar, october 20  in a major initiative a...  lives
# 1  he said in total, 25,000 quintals of wheat see...  lives
# 2  he said of this, nearly 9,000 quintals of seed...  lives
# 3   according to a proposal, farmers in 14 distri...  lives
# 4  ush({ });  according to estimates prepared by ...  lives

# %%
lives_df.loc[30].sentence
# Out:
# ' additionally, the dc sought rs 4 lakh for gratuitous loss due to the floods, rs 30 lakh for search, rescue and temporary shelters in flood-affected villages, rs 80 lakh for temporary accommodation, food and water and rs 15 lakh for clearing attached areas'

# %%
# keywords house/infastructure
house_keywords = [ 'house', 'home', 'roof', 'street', 'road', 'bridge', ]

imp_sentences(combined_df, house_keywords)
# Out:
#           date                                             source  \
# 0   2019-09-19  https://www.tribuneindia.com/news/punjab/flood...
# 1   2019-09-14  https://www.tribuneindia.com/news/punjab/jalan...
# 2   2019-09-14  https://www.tribuneindia.com/news/punjab/jalan...
# 3   2019-09-14  https://www.tribuneindia.com/news/punjab/jalan...
# 4   2019-09-13  https://www.tribuneindia.com/news/punjab/state...
# ..         ...                                                ...
# 754 2007-08-18                  https://reliefweb.int/node/240663
# 755 2007-08-17                  https://reliefweb.int/node/240777
# 756 2007-08-17                  https://reliefweb.int/node/240777
# 757 2007-07-17                  https://reliefweb.int/node/244592
# 758 2007-07-17                  https://reliefweb.int/node/244592
#
#                                               sentence
# 0    similarly, the government will give a compensa...
# 1     in jalandhar, the divisional commissioner and...
# 2    ush({ });  in kapurthala, crop losses have bee...
# 3     telling numbers  total loss  rs 526 crore  to...
# 4    tribune news service chandigarh/ropar, sept 12...
# ..                                                 ...
# 754   - 01 state and 36 panchayat roads were damage...
# 755  about 52 persons are reported to have been was...
# 756   - 01 state and 36 panchayat roads continue to...
# 757  - 26 panchayat and 06 state roads which were d...
# 758  - 01 landslide has also been reported in kodir...
#
# [759 rows x 3 columns]

# %%
# create dataframe 
houses_df = imp_sentences(combined_df, house_keywords)

# add column named to specify what type it is 
houses_df["topic"] = "house"

# check
houses_df.head()
# Out:
#         date                                             source  \
# 0 2019-09-19  https://www.tribuneindia.com/news/punjab/flood...
# 1 2019-09-14  https://www.tribuneindia.com/news/punjab/jalan...
# 2 2019-09-14  https://www.tribuneindia.com/news/punjab/jalan...
# 3 2019-09-14  https://www.tribuneindia.com/news/punjab/jalan...
# 4 2019-09-13  https://www.tribuneindia.com/news/punjab/state...
#
#                                             sentence  topic
# 0  similarly, the government will give a compensa...  house
# 1   in jalandhar, the divisional commissioner and...  house
# 2  ush({ });  in kapurthala, crop losses have bee...  house
# 3   telling numbers  total loss  rs 526 crore  to...  house
# 4  tribune news service chandigarh/ropar, sept 12...  house

# %%
houses_df.loc[5].sentence
# Out:
# ' according to a report submitted by the district administration, 46,300 residents in 182 villages were affected while standing crop on 11,580 acres and 313 houses were damaged completely'

# %% [markdown]
# ### combine the dataframe topics together into one dataframe

# %%
# list of all the dataframes which will be combined together
dataframes = [death_df, lives_df, agri_df, houses_df]

# combined dataframe
keyword_concat_df = pd.concat(dataframes, ignore_index=True)

# %%
keyword_concat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4255 entries, 0 to 4254
# Data columns (total 4 columns):
# date        4255 non-null datetime64[ns]
# source      4255 non-null object
# sentence    4255 non-null object
# topic       4255 non-null object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 133.1+ KB

# %%
total_keyword_one_search_df.info()

## combining all the keyword lists into separate areas adds on a little over 1000 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3399 entries, 0 to 3398
# Data columns (total 3 columns):
# date        3399 non-null datetime64[ns]
# source      3399 non-null object
# sentence    3399 non-null object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 79.8+ KB

# %%
total_keyword_one_search_df.loc[20].sentence
# Out:
# 'tribune news service  moga, october 13 the state government will provide high-quality wheat crop seeds to flood-hit farmers in moga, jalandhar, kapurthala, ferozepur, fazilka and other flood-affected districts for the upcoming rabi season'

# %% [markdown]
# ### find duplicated rows in the combined dataframe

# %%
keyword_concat_df[keyword_concat_df.duplicated(keep = False)].sort_values("source")
# Out:
#            date                                             source  \
# 399  2008-08-09                  https://reliefweb.int/node/275899
# 396  2008-08-09                  https://reliefweb.int/node/275899
# 395  2008-08-09                  https://reliefweb.int/node/275899
# 400  2008-08-09                  https://reliefweb.int/node/275899
# 398  2008-08-09                  https://reliefweb.int/node/275899
# ...         ...                                                ...
# 2905 2018-05-21  https://www.tribuneindia.com/news/punjab/shahk...
# 1036 2018-05-21  https://www.tribuneindia.com/news/punjab/shahk...
# 1033 2018-05-21  https://www.tribuneindia.com/news/punjab/shahk...
# 2758 2019-09-20  https://www.tribuneindia.com/news/punjab/then-...
# 2757 2019-09-20  https://www.tribuneindia.com/news/punjab/then-...
#
#                                                sentence  topic
# 399   - no human death has been reported in the stat...  death
# 396   - no human death has been reported in the stat...  death
# 395   - no human death has been reported in the stat...  death
# 400   - no human death has been reported in the stat...  death
# 398   - no human death has been reported in the stat...  death
# ...                                                 ...    ...
# 2905  farmers rue that despite huge damage, no one b...   agri
# 1036  farmers rue that despite huge damage, no one b...  lives
# 1033  farmers rue that despite huge damage, no one b...  lives
# 2758  but there is no shortage of material nor have ...   agri
# 2757  but there is no shortage of material nor have ...   agri
#
# [67 rows x 4 columns]

# %% [markdown]
# There are 67 duplicate rows. The duplicates make sense for the reliefweb articles since these articles report on multiple states and locations in one article and they repeat the sentence "no human death has been reported in ..." if there was no death in a location.

# %%
# Keeping the first appearance of a duplicated text
keyword_concat_df = keyword_concat_df.drop_duplicates( keep = "first")
keyword_concat_df = keyword_concat_df.reset_index()

# %%
# Reset the index
keyword_concat_df = keyword_concat_df.reset_index()

# %%
# check that dropped all duplicated rows
keyword_concat_df[keyword_concat_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [level_0, index, date, source, sentence, topic]
# Index: []

# %%
keyword_concat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4213 entries, 0 to 4212
# Data columns (total 6 columns):
# level_0     4213 non-null int64
# index       4213 non-null int64
# date        4213 non-null datetime64[ns]
# source      4213 non-null object
# sentence    4213 non-null object
# topic       4213 non-null object
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 197.6+ KB

# %% [markdown]
# Now we just keep the first appearance of a duplicate row. Now the dataframe is 4213 entries.

# %% [markdown]
# ## save to csv

# %%
# save to csv file 
# create csv file from the new dataframe

# dataframe of the individual searches combined together with a topic column!
keyword_concat_df.to_csv("../data/keyword_topic_sentences.csv", index = False)

# %%
keyword_concat_df.head()
# Out:
#    level_0  index       date  \
# 0        0      0 2019-09-14
# 1        1      1 2019-09-12
# 2        2      2 2019-09-03
# 3        3      3 2019-09-02
# 4        4      4 2019-08-27
#
#                                               source  \
# 0  https://www.tribuneindia.com/news/punjab/jalan...
# 1  https://www.tribuneindia.com/news/punjab/punja...
# 2  https://www.tribuneindia.com/news/punjab/rs-4-...
# 3  https://www.tribuneindia.com/news/punjab/power...
# 4  https://www.tribuneindia.com/news/punjab/distr...
#
#                                             sentence  topic
# 0  ush({ });  in kapurthala, crop losses have bee...  death
# 1  initial assessment  6 persons died  1,400 inju...  death
# 2  our correspondent fazilka, september 2  family...  death
# 3   as many as 25,000 personnel from different de...  death
# 4  in his desperate call to the pcr at 6.57 pm on...  death

# %% [markdown]
# **Summary**: One large topic concatenated dataframe was created and it has approximately 1000 more rows than a dataframe just passing through the combined keyword search. This means that that some of the sentences are being selected in multiple keyword searches. Next, this csv file will be used to create a SQL database and visuals to represent the findings.
